# %%
# Chunk by a set number of charactesr
def chunk_by_char(text, chunk_size=150, chunk_overlap=20):
    chunks = []
    start_idx = 0

    while start_idx < len(text):
        end_idx = min(start_idx + chunk_size, len(text))

        chunk_text = text[start_idx:end_idx]
        chunks.append(chunk_text)

        start_idx = (
            end_idx - chunk_overlap if end_idx < len(text) else len(text)
        )

    return chunks

# %%
# Chunk by sentence
import re


def chunk_by_sentence(text, max_sentences_per_chunk=5, overlap_sentences=1):
    sentences = re.split(r"(?<=[.!?])\s+", text)

    chunks = []
    start_idx = 0

    while start_idx < len(sentences):
        end_idx = min(start_idx + max_sentences_per_chunk, len(sentences))

        current_chunk = sentences[start_idx:end_idx]
        chunks.append(" ".join(current_chunk))

        start_idx += max_sentences_per_chunk - overlap_sentences

        if start_idx < 0:
            start_idx = 0

    return chunks

# %%
# Chunk by section
def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_char(text)

[print(chunk + "\n----\n") for chunk in chunks]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text)

[print(chunk + "\n----\n") for chunk in chunks]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_sentence(text=text, overlap_sentences=2, max_sentences_per_chunk=5)

[print(chunk + "\n----\n") for chunk in chunks]

# %%
# !pip install google-genai

from google import genai

client = genai.Client()

result = client.models.embed_content(
        model="gemini-embedding-2",
        contents="What is the meaning of life?"
)

print(result.embeddings)
# Out:
# Collecting google-genai
#   Downloading google_genai-2.17.0-py3-none-any.whl.metadata (56 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from google-genai) (4.9.0)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Downloading google_auth-2.56.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from google-genai) (0.28.1)
# Collecting pydantic<3.0.0,>=2.12.5 (from google-genai)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from google-genai) (9.1.2)
# Collecting websockets<17.0,>=13.0.0 (from google-genai)
#   Downloading websockets-16.1.1-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from google-genai) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (2.10)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Downloading cryptography-50.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.12.5->google-genai)
#   Downloading pydantic_core-2.46.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.12.5->google-genai)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Downloading cffi-2.1.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: pycparser in /home/jubaer/.asdf/installs/python/3.11.4/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.22)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Downloading pyasn1-0.6.4-py3-none-any.whl.metadata (8.4 kB)
# Downloading google_genai-2.17.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.4 MB/s  0:00:00
# Downloading google_auth-2.56.3-py3-none-any.whl (259 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.5 MB/s  0:00:00m eta 0:00:01
# Downloading websockets-16.1.1-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (186 kB)
# Downloading cryptography-50.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 4.4 MB/s  0:00:01m0:00:01:00:01
# Downloading cffi-2.1.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (217 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.4-py3-none-any.whl (84 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: websockets, typing-inspection, pydantic-core, pyasn1, cffi, pydantic, pyasn1-modules, cryptography, google-auth, google-genai
#   Attempting uninstall: typing-inspection━━━━━━━  0/10 [websockets]
#     Found existing installation: typing-inspection 0.4.1/10 [websockets]
#     Uninstalling typing-inspection-0.4.1:━━━  0/10 [websockets]
#       Successfully uninstalled typing-inspection-0.4.1 0/10 [websockets]
#   Attempting uninstall: pydantic-core━━━━━━━  0/10 [websockets]
#     Found existing installation: pydantic_core 2.33.2m 0/10 [websockets]
#     Uninstalling pydantic_core-2.33.2:━━━━━━  0/10 [websockets]
#       Successfully uninstalled pydantic_core-2.33.232m 0/10 [websockets]
#   Attempting uninstall: cffim╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/10 [pyasn1]c-core]
#     Found existing installation: cffi 1.17.1━━━━━━━━━━━━━━━━━━  3/10 [pyasn1]
#     Uninstalling cffi-1.17.1:m━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/10 [pyasn1]
#       Successfully uninstalled cffi-1.17.1m━━━━━━━━━━━━━━━━━━━━━━━  4/10 [cffi]
#   Attempting uninstall: pydanticm╺━━━━━━━━━━━━━━━━━━━━━━━  4/10 [cffi]
#     Found existing installation: pydantic 2.11.7━━━━━━━━━━━━━━  4/10 [cffi]
#     Uninstalling pydantic-2.11.7:╺━━━━━━━━━━━━━━━━━━━  5/10 [pydantic]
#       Successfully uninstalled pydantic-2.11.7━━━━━━━━━━━━━━━━  5/10 [pydantic]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [google-genai] [google-genai]s]
# Successfully installed cffi-2.1.1 cryptography-50.0.0 google-auth-2.56.3 google-genai-2.17.0 pyasn1-0.6.4 pyasn1-modules-0.4.2 pydantic-2.13.4 pydantic-core-2.46.4 typing-inspection-0.4.2 websockets-16.1.1
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip
# Reshimming asdf python...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       1 get_ipython().system('pip install google-genai')
#       3 from google import genai
# ----> 5 client = genai.Client()
#       7 result = client.models.embed_content(
#       8         model="gemini-embedding-2",
#       9         contents="What is the meaning of life?"
#      10 )
#      12 print(result.embeddings)
#
# File ~/.asdf/installs/python/3.11.4/lib/python3.11/site-packages/google/genai/client.py:379, in Client.__init__(self, enterprise, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     376   else:
#     377     http_options = HttpOptions(base_url=base_url)
# --> 379 self._api_client = self._get_api_client(
#     380     vertexai=resolved_vertexai,
#     381     api_key=api_key,
#     382     credentials=credentials,
#     383     project=project,
#     384     location=location,
#     385     debug_config=self._debug_config,
#     386     http_options=http_options,
#     387 )
#     389 self._aio = AsyncClient(self._api_client)
#     390 self._models = Models(self._api_client)
#
# File ~/.asdf/installs/python/3.11.4/lib/python3.11/site-packages/google/genai/client.py:432, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     415 if debug_config and debug_config.client_mode in [
#     416     'record',
#     417     'replay',
#     418     'auto',
#     419 ]:
#     420   return ReplayApiClient(
#     421       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     422       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    429       http_options=http_options,
#     430   )
# --> 432 return BaseApiClient(
#     433     vertexai=vertexai,
#     434     api_key=api_key,
#     435     credentials=credentials,
#     436     project=project,
#     437     location=location,
#     438     http_options=http_options,
#     439 )
#
# File ~/.asdf/installs/python/3.11.4/lib/python3.11/site-packages/google/genai/_api_client.py:794, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     792 else:  # Implicit initialization or missing arguments.
#     793   if not self.api_key:
# --> 794     raise ValueError(
#     795         'No API key was provided. Please pass a valid API key. Learn how to'
#     796         ' create an API key at'
#     797         ' https://ai.google.dev/gemini-api/docs/api-key.'
#     798     )
#     799   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     800   self._http_options.api_version = 'v1beta'
#
# ValueError: No API key was provided. Please pass a valid API key. Learn how to create an API key at https://ai.google.dev/gemini-api/docs/api-key.
